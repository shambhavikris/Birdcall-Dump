# %%
# !pip install pydub
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1

# %%
import os
import tensorflow as tf
import pydub
import numpy as np

# %%
def convert_wav_to_tr

# %%
dir = '/content/drive/My Drive/lala1/train_audio/dataupload residual'

ms_of_data = 30000*30

for d in os.listdir(dir):

  folder = os.path.join(dir, d)
  #print('folder', folder)
  num1 = 1

  for f in os.listdir(folder):
    # each .mp3 file
    fn = os.path.join(folder, f)
    print('fn', fn)
    x = pydub.AudioSegment.from_file(file=fn)
    os.remove(fn)
    x = x.set_frame_rate(30000)
    x = x.set_sample_width(1)
    x = np.array(x.get_array_of_samples(), dtype=np.float32)
    x = np.trim_zeros(x)
    num = len(x)//ms_of_data
    if num==0:
      x = np.pad(x, (0, ms_of_data - len(x)))
    x = x[0:(len(x)//ms_of_data)*ms_of_data]
    # print(str(num1), 'windows', str(len(x)//ms_of_data))
    x = np.array(np.split(x, len(x)//ms_of_data))
    num2 = 1

    for i in x:
      filename = dir+'/'+d+'/'+d+'_'+str(num1)+'_'+str(num2)+'.wav'
      audio_segment = pydub.AudioSegment(i.tobytes(), frame_rate=30000, sample_width=i.dtype.itemsize, channels=1)
      audio_segment.export(filename, format="wav")
      print(audio_segment)
      print(filename)
      num2 = num2+1

    num1 = num1+1
# Out:
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC109768.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a9b0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_1_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114551.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ad68>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_2_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114554.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af60>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_3_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC112829.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a978>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_4_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af60>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_4_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a978>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_4_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af60>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_4_4.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC112598.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ad68>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_5_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af60>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_5_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ad68>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_5_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af60>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_5_4.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114550.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acf8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_6_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114552.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ac50>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_7_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114557.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ac88>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_8_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC131445.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ada0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_9_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC137865.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ae48>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_10_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ada0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_10_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ae48>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_10_3.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC121396.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ac88>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_11_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ae48>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_11_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ac88>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_11_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ae48>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_11_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ac88>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_11_5.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC115940.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ada0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_12_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114558.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa58>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_13_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114559.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab00>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_14_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC115938.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ada0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_15_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114555.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a940>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_16_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC134495.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab70>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_17_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a940>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_17_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab70>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_17_3.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114561.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ae80>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_18_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC126022.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a9e8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_19_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC115939.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aeb8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_20_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114560.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_21_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC114556.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_22_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC131447.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_23_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC160880.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_24_8.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC155440.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_25_6.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC172427.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_26_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_26_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC160878.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_27_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_27_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_27_3.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC155441.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48a3c8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_28_15.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC167792.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_29_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_29_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48ab38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_29_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48af98>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_29_4.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC172881.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa20>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_30_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC172878.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_31_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC172882.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_32_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC172875.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_33_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC181497.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_34_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_34_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_34_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_34_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_34_5.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC188842.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_35_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_35_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_35_3.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC191952.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_36_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC191954.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_37_8.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC187481.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_38_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC180081.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_39_6.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC233496.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_40_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC206082.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_41_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_41_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_41_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_41_4.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC193111.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48aa90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_42_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_42_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC268481.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_43_7.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC197261.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_44_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_44_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_44_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf48acc0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_44_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210048>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_44_5.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC195540.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_45_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC193112.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210940>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_46_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_46_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC197260.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210860>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_47_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_47_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC197259.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210080>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_48_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC279723.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2102e8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_49_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC309641.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210198>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_50_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC289011.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210ac8>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_51_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC293246.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2106a0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_52_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC279721.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210b38>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_53_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2106a0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_53_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC293291.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210b70>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_54_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2106a0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_54_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210b70>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_54_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2106a0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_54_4.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC293812.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210828>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_55_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC296308.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210198>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_56_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC314874.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210a90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_57_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC316302.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_58_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210a90>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_58_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_58_3.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC312752.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_15.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_16.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_17.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_18.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210908>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_19.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2101d0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_59_20.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC317205.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210630>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_60_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC318014.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210c18>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_61_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210630>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_61_2.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC315688.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210c50>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_62_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC325096.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2106a0>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_63_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC320383.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210c88>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_64_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/XC345874.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf210518>
# /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/amecro_65_1.wav
# fn /content/drive/My Drive/lala1/train_audio/dataupload residual/amecro/X
    x = pydub.AudioSegment.from_file(file=fn)
    os.remove(fn)
    x = x.set_frame_rate(30000)
    x = x.set_sample_width(1)
    x = np.array(x.get_array_of_samples(), dtype=np.float32)
    x = np.trim_zeros(x)
    num = len(x)//ms_of_data
    if num==0:
      x = np.pad(x, (0, ms_of_data - len(x)))
    x = x[0:(len(x)//ms_of_data)*ms_of_data]
    # print(str(num1), 'windows', str(len(x)//ms_of_data))
    x = np.array(np.split(x, len(x)//ms_of_data))
    num2 = 1

    for i in x:
      filename = dir+'/'+d+'/'+d+'_'+str(num1)+'_'+str(num2)+'.wav'
      audio_segment = pydub.AudioSegment(i.tobytes(), frame_rate=30000, sample_width=i.dtype.itemsize, channels=1)
      audio_segment.export(filename, format="wav")
      print(audio_segment)
      print(filename)
      num2 = num2+1

    num1 = num1+1
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/lala1/train_audio/data_upload Final/ovenbi1/ovenbi1_100_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/ovenbi1/ovenbi1_100_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/ovenbi1/ovenbi1_100_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC153656.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244668>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_1_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC111161.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_2_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC130979.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244780>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_3_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC135091.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_4_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC153657.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2446a0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_5_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC130980.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_6_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC135093.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2449b0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_7_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_7_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf2449b0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_7_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC127637.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_8_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189604.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_9_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_9_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_9_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC176262.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_10_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189602.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_11_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244390>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_11_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_11_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC173794.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_12_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189084.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_13_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_13_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_13_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_13_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC17030.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_14_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC17029.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_15_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC17032.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_16_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC177140.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_17_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_17_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC17031.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_18_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC179094.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_19_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_19_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_19_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_19_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_19_5.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189603.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_20_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_20_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_20_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_20_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189083.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_21_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC181476.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_22_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC313389.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_23_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189609.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_24_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_24_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_24_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC307682.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_25_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189612.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_26_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_26_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_26_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC265800.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_27_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_27_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_27_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC239650.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_28_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_28_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189605.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_29_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_29_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_29_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_29_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC243410.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_30_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC212778.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_31_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_31_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_31_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_31_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_31_5.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC298977.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_32_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC189607.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_33_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC247860.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_34_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_34_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_34_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_34_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_34_5.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC410779.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_35_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_35_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_35_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC405013.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_36_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC416801.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244ba8>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_37_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC466699.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_38_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC318274.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244da0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_39_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_39_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC460773.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244550>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_40_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_40_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC468574.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_41_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC318281.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_42_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC466921.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_43_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_43_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC313824.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_44_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC476809.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_45_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/XC54140.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/palwar/palwar_46_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC124175.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_1_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC120620.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244ac8>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_2_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC127852.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_3_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC145670.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_4_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC120655.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_5_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC149448.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_6_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC132843.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_7_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC167846.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_8_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC177091.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_9_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_9_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC149450.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_10_7.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC149453.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244438>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_11_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC149452.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_12_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244438>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_12_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_12_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC150069.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_13_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC177947.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_14_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC178128.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_15_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC178047.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_16_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_16_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_16_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_16_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_16_5.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC178130.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_15.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_16.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_17.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_18.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_19.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_17_20.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC178131.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_18_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_18_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_18_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC178153.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_19_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC189085.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_20_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC182147.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_21_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_21_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC179049.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_22_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_22_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_22_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_22_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_22_5.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC189217.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_23_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC188928.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_24_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_24_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_24_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_24_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC189216.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_25_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC182058.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_26_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_26_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC188422.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_27_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC193157.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_28_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC210418.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_29_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC192964.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_30_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC208979.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_31_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC210416.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_32_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC193155.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_33_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC196041.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_34_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC206473.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_35_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC192527.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_36_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC210417.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_37_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC332900.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_38_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC314114.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_39_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC372219.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_40_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_40_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_40_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC243924.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_41_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC330000.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a20>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_42_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC367192.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_43_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a20>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_43_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_43_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a20>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_43_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC239360.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_44_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a20>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_44_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_44_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC288699.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_45_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC293321.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_46_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC240293.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_47_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_47_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC331677.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_48_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC287994.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_49_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC333900.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_50_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC313531.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_51_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_51_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_51_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_51_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC331257.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_52_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_52_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC261090.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_53_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC236931.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_54_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_54_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC293104.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_55_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_55_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_55_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC388418.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_56_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC406243.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_57_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_57_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_57_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_57_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC388167.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_15.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_16.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231198>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_17.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_58_18.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC387766.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_59_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_59_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_59_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC388146.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_60_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC386249.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_61_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_61_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_61_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC386250.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_62_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_62_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC411886.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_63_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC406244.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_64_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_64_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_64_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC415058.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_65_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_65_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_65_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC416169.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_66_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_66_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC417185.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a90>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_67_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC406252.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231828>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_68_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a90>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_68_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/XC414207.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_69_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf244a90>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_69_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bdac4b908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/norwat/norwat_69_3.wav
# ...
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_50.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_51.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_52.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_53.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_54.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_55.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_56.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_57.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_58.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_59.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_60.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_88_61.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC482525.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_89_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_89_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC469896.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_90_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC488965.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_91_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_91_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC490227.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_92_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_92_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_92_3.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC489315.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231748>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_93_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC503419.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_94_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC501837.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_95_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC498056.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_96_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC503060.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_97_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_97_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC62791.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_98_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_98_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_98_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_98_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC54018.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231be0>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_99_11.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/XC503815.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_15.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/normoc/normoc_100_16.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC169012.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231240>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_1_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC254429.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_2_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC205426.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_3_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC253329.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_4_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC254430.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231908>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_5_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC205471.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_6_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC294560.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_7_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC147391.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_8_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC147390.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_9_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC294780.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_10_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC351732.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_11_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC294775.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_12_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_12_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_12_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_12_4.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC294915.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_13_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_13_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC325007.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_14_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC386247.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf247470>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_15_6.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC349275.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_16_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC302522.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231400>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_17_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC345776.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_18_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC295403.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_19_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f6bcf231898>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_19_2.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC453335.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f6c0592a588>
# /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/moublu_20_1.wav
# fn /content/drive/My Drive/lala1/train_audio/data_upload Final/moublu/XC441350.mp3

# %%
import os
import tensorflow as tf
import pydub
import numpy as np

dir = '/content/drive/My Drive/lala1/train_audio/DataUpload'

ms_of_data = 30000*30

for d in os.listdir(dir):

  folder = os.path.join(dir, d)
  #print('folder', folder)
  num1 = 1

  for f in os.listdir(folder):
    # each .mp3 file
    fn = os.path.join(folder, f)
    print('fn', fn)
    x = pydub.AudioSegment.from_file(file=fn)
    os.remove(fn)
    x = x.set_frame_rate(30000)
    x = x.set_sample_width(1)
    x = np.array(x.get_array_of_samples(), dtype=np.float32)
    x = np.trim_zeros(x)
    num = len(x)//ms_of_data
    if num==0:
      x = np.pad(x, (0, ms_of_data - len(x)))
    x = x[0:(len(x)//ms_of_data)*ms_of_data]
    # print(str(num1), 'windows', str(len(x)//ms_of_data))
    x = np.array(np.split(x, len(x)//ms_of_data))
    num2 = 1

    for i in x:
      filename = dir+'/'+d+'/'+d+'_'+str(num1)+'_'+str(num2)+'.wav'
      audio_segment = pydub.AudioSegment(i.tobytes(), frame_rate=30000, sample_width=i.dtype.itemsize, channels=1)
      audio_segment.export(filename, format="wav")
      print(audio_segment)
      print(filename)
      num2 = num2+1

    num1 = num1+1
# Out:
# Streaming output truncated to the last 5000 lines.
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230208>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_79_11.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC390276.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22ea90>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_80_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC381309.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230a20>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_81_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC383972.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_82_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230a20>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_82_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_82_3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC388164.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230908>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_83_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_83_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC383954.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22ea90>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_84_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC390598.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22edd8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_85_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22ea90>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_85_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC418002.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22edd8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_86_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC391090.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e7f0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_87_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC415889.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22ea90>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_88_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e7f0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori_88_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/balori/XC428772.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22ea90>
# /content/drive/My Drive/lala1/train_audio/DataUpload/balori/balori
3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC143748.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_16_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC169069.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_17_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_17_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC172900.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_18_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_18_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_18_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_18_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC144696.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_19_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_19_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_19_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230518>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_19_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_19_5.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC168795.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2305c0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_20_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC141412.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/bawwar_21_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/bawwar/XC167817.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230588>
# ...
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_53_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC358052.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_54_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230a20>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_54_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_54_3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC362651.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230048>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_55_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC388694.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_56_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC360916.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230780>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_57_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC358027.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230470>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_58_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC370196.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_59_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC416032.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_60_6.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC416031.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230240>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_61_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d296588>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_61_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC407173.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230208>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_62_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC416029.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e7f0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_63_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230208>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_63_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d22e7f0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_63_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230208>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_63_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC445610.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230748>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_64_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC418105.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2305f8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_65_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230748>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_65_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC418099.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_66_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230748>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_66_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_66_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230748>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_66_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_66_5.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC461241.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230828>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_67_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_67_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230828>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_67_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_67_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC418101.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230860>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_68_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC418103.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2302e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_69_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230860>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_69_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2302e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_69_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230860>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_69_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC461183.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2302e8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_70_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC461242.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_71_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC463343.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_6.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_7.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_8.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_9.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_10.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_11.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_12.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_13.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_14.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230160>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_15.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_72_16.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC464355.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230b00>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230b00>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230b00>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_5.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_73_6.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC475141.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230438>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_74_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_74_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230438>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_74_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_74_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC471244.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_75_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230ac8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_75_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_75_3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC476517.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230320>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_76_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_76_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230320>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_76_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_76_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC467316.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_77_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_77_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_77_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2309b0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_77_4.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_77_5.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC51754.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230128>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_78_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_78_2.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC51755.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230a20>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_79_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_79_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230a20>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_79_3.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2304a8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_79_4.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC473284.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230b38>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_80_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC475138.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230780>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_81_1.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC99969.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_82_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d230780>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_82_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_82_3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/XC78342.mp3
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2308d0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_83_1.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2303c8>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_83_2.wav
# <pydub.audio_segment.AudioSegment object at 0x7f2b1d2308d0>
# /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amewoo_83_3.wav
# fn /content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amerob
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-17-d50a20d71da3> in <module>()
#      18     fn = os.path.join(folder, f)
#      19     print('fn', fn)
# ---> 20     x = pydub.AudioSegment.from_file(file=fn)
#      21     os.remove(fn)
#      22     x = x.set_frame_rate(30000)
#
# /usr/local/lib/python3.6/dist-packages/pydub/audio_segment.py in from_file(cls, file, format, codec, parameters, **kwargs)
#     620         except TypeError:
#     621             filename = None
# --> 622         file, close_file = _fd_or_path_or_tempfile(file, 'rb', tempfile=False)
#     623
#     624         if format:
#
# /usr/local/lib/python3.6/dist-packages/pydub/utils.py in _fd_or_path_or_tempfile(fd, mode, tempfile)
#      58
#      59     if isinstance(fd, basestring):
# ---> 60         fd = open(fd, mode=mode)
#      61         close_fd = True
#      62
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/My Drive/lala1/train_audio/DataUpload/amewoo/amerob'

# %%
t = '/content/drive/My Drive/lala1/train_audio/DataUpload/caster1/XC119938.mp3'
t = pydub.AudioSegment.from_file(file=fn)
# os.remove(fn)
x = t.set_frame_rate(30000)
x = x.set_sample_width(1)
x = np.array(x.get_array_of_samples(), dtype=np.float32)
x = np.trim_zeros(x)
# print(str(num1), 'windows', str(len(x)//ms_of_data))

print(x.shape)
num = len(x)//ms_of_data
if num==0:
  x = np.pad(x, (0, ms_of_data - len(x)))
x = x[0:(len(x)//ms_of_data)*ms_of_data]

x = np.array(np.split(x, len(x)//ms_of_data))
# Out:
# (628208,)

# %%
arr = np.array([1, 2, 3, 4])
print(arr.shape)
np.pad(arr, (0, 3))
# Out:
# (4,)
# array([1, 2, 3, 4, 0, 0, 0])

# %%
print('done with data upload folder')
# Out:
# done with data upload folder
