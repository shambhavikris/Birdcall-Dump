# %%
# %cd /content/drive/"My drive"/.../my_folder
! zip -r archive_name.zip my_folder

# %%
cd /content/drive/My Drive/lala1
# Out:
# /content/drive/My Drive/lala1

# %%
! zip -r data_5sec.zip Data-5Seconds/
# Out:
#   adding: Data-5Seconds/ (stored 0%)
#   adding: Data-5Seconds/Train/ (stored 0%)
#   adding: Data-5Seconds/Train/lewwoo_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/lesgol_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/lesyel_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/wesgre_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/tuftit_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/linspa_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/vesspa_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/logshr_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/louwat_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/warvir_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/truswa_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/lobcur_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/vigswa_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/wessan_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/lobdow_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/tunswa_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/lotduc_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/lesnig_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/veery_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/larspa_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/leabit_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/treswa_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/lazbun_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/solsan_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/swahaw_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/killde_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/stejay_train.tfrecord (deflated 1%)
#   adding: Data-5Seconds/Train/labwoo_train.tfrecord (deflated 3%)
#   adding: Data-5Seconds/Train/leasan_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/indbun_train.tfrecord (deflated 2%)
#   adding: Data-5Seconds/Train/swaspa_train.tfrecord
